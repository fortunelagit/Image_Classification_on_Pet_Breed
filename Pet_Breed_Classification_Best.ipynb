# %% [markdown]
# <a href="https://colab.research.google.com/github/fortunelagit/Image_Classification_on_Pet_Breed/blob/main/Pet_Breed_Classification_Best.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Pet Breed Classsification using CNN**

# %% [markdown]
# 1. Mount dataset yang sudah dibagi menjadi folder berdasarkan classnya.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Pastikan dataset untuk training terdiri dari 37 class.

# %%
import os

dir = '/content/drive/MyDrive/01_dataset_pet/pet_breed_dataset'

data_dir_list = os.listdir(dir)
print('Folders :', os.listdir(dir))
classes = sorted(os.listdir(dir+'/train'))
file_count = len(classes)
print(len(classes), 'class', classes)
# Out:
# Folders : ['train', 'final_test', '.ipynb_checkpoints', 'variables', 'assets', 'fingerprint.pb', 'saved_model.pb', 'keras_metadata.pb']
# 37 class ['Abyssinian', 'American_Bulldog', 'American_Pitbull_Terrier', 'Basset_Hound', 'Beagle', 'Bengal', 'Birman', 'Bombay', 'Boxer', 'British_Shorthair', 'Chihuahua', 'Egyptian_Mau', 'English_Cocker_Spaniel', 'English_Setter', 'German_Shorthaired', 'Great_Pyrenees', 'Havanese', 'Japanese_Chin', 'Keeshond', 'Leonberger', 'Maine_Coon', 'Miniature_Pinscher', 'Newfoundland', 'Persian', 'Pomeranian', 'Pug', 'Ragdoll', 'Russian_Blue', 'Saint_Bernard', 'Samoyed', 'Scottish_Terrier', 'Shiba_Inu', 'Siamese', 'Sphynx', 'Staffordshire_Bull_Terrier', 'Wheaten_Terrier', 'Yorkshire_Terrier']

# %% [markdown]
# 2. Split dataset training menjadi 2 bagian untuk training dan validation.

# %%
train_dataset_dir = '/content/drive/MyDrive/01_dataset_pet/pet_breed_dataset/train/'
base_dir = '/content/dataset/'
os.mkdir(base_dir)

# %%
train_dir = os.path.join(base_dir, 'train')
os.mkdir(train_dir)

validation_dir = os.path.join(base_dir, 'validation')
os.mkdir(validation_dir)

test_dir = os.path.join(base_dir, 'test')
os.mkdir(test_dir)

for i in classes:
  train_class_dir = os.path.join(train_dir, i)
  os.mkdir(train_class_dir)

  valid_class_dir = os.path.join(validation_dir, i)
  os.mkdir(valid_class_dir)

  #test_class_dir = os.path.join(test_dir, i)
  #os.mkdir(test_class_dir)

# %%
print(classes)
# Out:
# ['Abyssinian', 'American_Bulldog', 'American_Pitbull_Terrier', 'Basset_Hound', 'Beagle', 'Bengal', 'Birman', 'Bombay', 'Boxer', 'British_Shorthair', 'Chihuahua', 'Egyptian_Mau', 'English_Cocker_Spaniel', 'English_Setter', 'German_Shorthaired', 'Great_Pyrenees', 'Havanese', 'Japanese_Chin', 'Keeshond', 'Leonberger', 'Maine_Coon', 'Miniature_Pinscher', 'Newfoundland', 'Persian', 'Pomeranian', 'Pug', 'Ragdoll', 'Russian_Blue', 'Saint_Bernard', 'Samoyed', 'Scottish_Terrier', 'Shiba_Inu', 'Siamese', 'Sphynx', 'Staffordshire_Bull_Terrier', 'Wheaten_Terrier', 'Yorkshire_Terrier']

# %%
import csv

with open(base_dir + 'test_set.csv', 'w') as outfile:
  csv_writer = csv.writer(outfile)
  line = ['filename','class']
  csv_writer.writerow(line)

# %%
import random
import shutil

def split_data(SOURCE, TRAINING, VALIDATION, TESTING, SPLIT_SIZE, CLASS_INDEX):
    files = []
    for filename in os.listdir(SOURCE):
        file = SOURCE + filename
        if os.path.getsize(file) > 0:
            #print(filename)
            files.append(filename)
        else:
            print(filename + " is zero length, so ignoring.")

    valid_size = 0.85
    training_length = int(len(files) * SPLIT_SIZE)
    valid_length = int((len(files) - training_length)*valid_size)
    test_length = int((len(files) - training_length)*(1-valid_size))

    shuffled_set = random.sample(files, len(files))
    training_set = shuffled_set[0:training_length]
    valid_set = shuffled_set[training_length:training_length+valid_length]
    test_set = shuffled_set[training_length+valid_length:]

    for filename in training_set:
        this_file = SOURCE + filename
        destination = TRAINING + filename
        shutil.copyfile(this_file, destination)

    for filename in valid_set:
        this_file = SOURCE + filename
        destination = VALIDATION + filename
        shutil.copyfile(this_file, destination)
    
    for filename in test_set:
        this_file = SOURCE + filename
        destination = TESTING + filename
        shutil.copyfile(this_file, destination)
        with open(base_dir + 'test_set.csv', 'a') as outfile:
          csv_writer = csv.writer(outfile)
          line = [filename,CLASS_INDEX]
          csv_writer.writerow(line)

# %%
split_size = .8

source_dir = train_dataset_dir
train_dir = os.path.join(base_dir, 'train')
valid_dir = os.path.join(base_dir, 'validation')
test_dir = os.path.join(base_dir, 'test')

classes_index = 0

for i in classes:
  class_source_dir = os.path.join(source_dir, i)
  #print(class_source_dir)
  class_train_dir = os.path.join(train_dir, i)
  class_valid_dir = os.path.join(valid_dir, i)
  #class_test_dir = os.path.join(test_dir, i)

  #print(class_train_dir)
  split_data(class_source_dir + '/', class_train_dir + '/', class_valid_dir + '/', test_dir + '/', split_size, f'{classes_index}')
  classes_index += 1

# %% [markdown]
# Distribusi dataset untuk Training:

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.image import imread
import pathlib

nimgs = {}
for i in classes:
    nimages = len(os.listdir(train_dir + '/' + i + '/'))
    nimgs[i]=nimages
plt.figure(figsize=(9, 6))
plt.bar(range(len(nimgs)), list(nimgs.values()), align='center')
plt.xticks(range(len(nimgs)), list(nimgs.keys()))
plt.title('Distribution of different classes in Training Dataset')
plt.show()

# %%
for i in classes:
    print('Training {} images are: '.format(i)+str(len(os.listdir(train_dir + '/' + i + '/'))))
# Out:
# Training Abyssinian images are: 187
# Training American_Bulldog images are: 190
# Training American_Pitbull_Terrier images are: 193
# Training Basset_Hound images are: 197
# Training Beagle images are: 190
# Training Bengal images are: 188
# Training Birman images are: 193
# Training Bombay images are: 180
# Training Boxer images are: 189
# Training British_Shorthair images are: 194
# Training Chihuahua images are: 191
# Training Egyptian_Mau images are: 180
# Training English_Cocker_Spaniel images are: 187
# Training English_Setter images are: 191
# Training German_Shorthaired images are: 191
# Training Great_Pyrenees images are: 191
# Training Havanese images are: 191
# Training Japanese_Chin images are: 192
# Training Keeshond images are: 190
# Training Leonberger images are: 194
# Training Maine_Coon images are: 194
# Training Miniature_Pinscher images are: 191
# Training Newfoundland images are: 188
# Training Persian images are: 193
# Training Pomeranian images are: 192
# Training Pug images are: 188
# Training Ragdoll images are: 190
# Training Russian_Blue images are: 195
# Training Saint_Bernard images are: 188
# Training Samoyed images are: 191
# Training Scottish_Terrier images are: 195
# Training Shiba_Inu images are: 192
# Training Siamese images are: 191
# Training Sphynx images are: 194
# Training Staffordshire_Bull_Terrier images are: 181
# Training Wheaten_Terrier images are: 194
# Training Yorkshire_Terrier images are: 192

# %% [markdown]
# Distibrusi dataset untuk validasi:

# %%
nimgs = {}
for i in classes:
    nimages = len(os.listdir(valid_dir + '/' + i + '/'))
    nimgs[i]=nimages
plt.figure(figsize=(9, 6))
plt.bar(range(len(nimgs)), list(nimgs.values()), align='center')
plt.xticks(range(len(nimgs)), list(nimgs.keys()))
plt.title('Distribution of different classes in Validation Dataset')
plt.show()

# %% [markdown]
# 3. Pembuatan Model CNN

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %% [markdown]
# Ukuran width dan height yang kecil akan mempersingkat waktu training.

# %%
img_width=300; img_height=300
batch_size=64

# %%
train_datagen = ImageDataGenerator(rescale = 1/255.0,
                                   rotation_range=30,
                                   zoom_range=0.4,
                                   horizontal_flip=True)

train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    target_size=(img_height, img_width))
# Out:
# Found 7048 images belonging to 37 classes.

# %%
validation_datagen = ImageDataGenerator(rescale = 1/255.0)

validation_generator = validation_datagen.flow_from_directory(valid_dir,
                                                              batch_size=batch_size,
                                                              class_mode='categorical',
                                                              target_size=(img_height, img_width)
                                                             )
# Out:
# Found 2278 images belonging to 37 classes.

# %% [markdown]
# Simpan model terbaik yang dihasilkan.

# %%
callbacks = EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='auto')

best_model_file = '/content/CNN_aug_best_weights.h5'
best_model = ModelCheckpoint(best_model_file, monitor='val_accuracy', verbose = 1, save_best_only = True)

# %%
model = Sequential([
    Conv2D(16, (3, 3), activation='relu', input_shape=(img_height, img_width, 3)), MaxPooling2D(2, 2),
    Conv2D(32, (3, 3), activation='relu'), 
    MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(256, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(512, activation='relu'),
    Dense(37, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 298, 298, 16)      448
#
#  max_pooling2d_5 (MaxPooling  (None, 149, 149, 16)     0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 147, 147, 32)      4640
#
#  max_pooling2d_6 (MaxPooling  (None, 73, 73, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 71, 71, 64)        18496
#
#  max_pooling2d_7 (MaxPooling  (None, 35, 35, 64)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 33, 33, 128)       73856
#
#  max_pooling2d_8 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 14, 14, 256)       295168
#
#  max_pooling2d_9 (MaxPooling  (None, 7, 7, 256)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 12544)             0
#
#  dense_2 (Dense)             (None, 512)               6423040
#
#  dense_3 (Dense)             (None, 37)                18981
#
# =================================================================
# Total params: 6,834,629
# Trainable params: 6,834,629
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 4. Compile Model

# %%
model.compile(optimizer='Adam', 
              loss='categorical_crossentropy', 
              metrics =['accuracy'])

# %% [markdown]
# 5. Training Model

# %% [markdown]
# Fungsi reduce learning rate ditambahkan untuk mitigasi nilai akurasi yang terus turun, yang kemungkinan disebabkan oleh learning rate yang terlalu tinggi.

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
import numpy as np

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)

# %%
history = model.fit(train_generator,
                              epochs=50,
                              verbose=1,
                              validation_data=validation_generator,
                              callbacks = [best_model, reduce_lr]
                              )
# Out:
# Epoch 1/50
# 111/111 [==============================] - ETA: 0s - loss: 2.6847 - accuracy: 0.2463
# Epoch 1: val_accuracy improved from -inf to 0.31124, saving model to /content/CNN_aug_best_weights.h5
# 111/111 [==============================] - 201s 2s/step - loss: 2.6847 - accuracy: 0.2463 - val_loss: 2.4593 - val_accuracy: 0.3112 - lr: 0.0010
# Epoch 2/50
# 111/111 [==============================] - ETA: 0s - loss: 2.5597 - accuracy: 0.2733
# Epoch 2: val_accuracy improved from 0.31124 to 0.33099, saving model to /content/CNN_aug_best_weights.h5
# 111/111 [==============================] - 200s 2s/step - loss: 2.5597 - accuracy: 0.2733 - val_loss: 2.3355 - val_accuracy: 0.3310 - lr: 0.0010
# Epoch 3/50
# 111/111 [==============================] - ETA: 0s - loss: 2.4270 - accuracy: 0.3059
# Epoch 3: val_accuracy improved from 0.33099 to 0.37226, saving model to /content/CNN_aug_best_weights.h5
# 111/111 [==============================] - 199s 2s/step - loss: 2.4270 - accuracy: 0.3059 - val_loss: 2.2234 - val_accuracy: 0.3723 - lr: 0.0010
# Epoch 4/50
# 111/111 [==============================] - ETA: 0s - loss: 2.3125 - accuracy: 0.3361
# Epoch 4: val_accuracy improved from 0.37226 to 0.40123, saving model to /content/CNN_aug_best_weights.h5
# 111/111 [==============================] - 200s 2s/step - loss: 2.3125 - accuracy: 0.3361 - val_loss: 2.0583 - val_accuracy: 0.4012 - lr: 0.0010
# Epoch 5/50
# 111/111 [==============================] - ETA: 0s - loss: 2.1903 - accuracy: 0.3632
# Epoch 5: val_accuracy improved from 0.40123 to 0.43898, saving model to /content/CNN_aug_best_weights.h5
# 111/111 [==============================] - 198s 2s/step - loss: 2.1903 - accuracy: 0.3632 - val_loss: 1.9911 - val_accuracy: 0.4390 - lr: 0.0010
# Epoch 6/50
# 111/111 [==============================] - ETA: 0s - loss: 2.1260 - accuracy: 0.3849
# Epoch 6: val_accuracy improved from 0.43898 to 0.48859, saving model to /content/CNN_aug_best_weights.h5
# 111/111 [==============================] - 197s 2s/step - loss: 2.1260 - accuracy: 0.3849 - val_loss: 1.7687 - val_accuracy: 0.4886 - lr: 0.0010
# Epoch 7/50
# 111/111 [==============================] - ETA: 0s - loss: 2.0254 - accuracy: 0.4108
# Epoch 7: val_accuracy improved from 0.48859 to 0.50966, saving model to /content/CNN_aug_best_weights.h5
# 111/111 [==============================] - 197s 2s/step - loss: 2.0254 - accuracy: 0.4108 - val_loss: 1.6727 - val_accuracy: 0.5097 - lr: 0.0010
# Epoch 8/50
# 111/111 [==============================] - ETA: 0s - loss: 1.9185 - accuracy: 0.4367
# Epoch 8: val_accuracy improved from 0.50966 to 0.55312, saving model to /content/CNN_aug_best_weights.h5
# 111/111 [==============================] - 201s 2s/step - loss: 1.9185 - accuracy: 0.4367 - val_loss: 1.5445 - val_accuracy: 0.5531 - lr: 0.0010
# Epoch 9/50
# 111/111 [==============================] - ETA: 0s - loss: 1.8075 - accuracy: 0.4664
# Epoch 9: val_accuracy did not improve from 0.55312
# 111/111 [==============================] - 198s 2s/step - loss: 1.8075 - accuracy: 0.4664 - val_loss: 1.6166 - val_accuracy: 0.5268 - lr: 0.0010
# Epoch 10/50
# 111/111 [==============================] - ETA: 0s - loss: 1.7396 - accuracy: 0.4828
# Epoch 10: val_accuracy improved from 0.55312 to 0.58297, saving model to /content/CNN_aug_best_weights.h5
# 111/111 [==============================] - 197s 2s/step - loss: 1.7396 - accuracy: 0.4828 - val_loss: 1.4267 - val_accuracy: 0.5830 - lr: 0.0010
# Epoch 11/50
# 111/111 [==============================] - ETA: 0s - loss: 1.6625 - accuracy: 0.5062
# Epoch 11: val_accuracy did not improve from 0.58297
# 111/111 [==============================] - 198s 2s/step - loss: 1.6625 - accuracy: 0.5062 - val_loss: 1.4809 - val_accuracy: 0.5742 - lr: 0.0010
# Epoch 12/50
# 111/111 [==============================] - ETA: 0s - loss: 1.6154 - accuracy: 0.5243
# Epoch 12: val_accuracy improved from 0.58297 to 0.62467, saving model to /content/CNN_aug_best_weights.h5
# 111/111 [==============================] - 198s 2s/step - loss: 1.6154 - accuracy: 0.5243 - val_loss: 1.2760 - val_accuracy: 0.6247 - lr: 0.0010
# Epoch 13/50
# 111/111 [==============================] - ETA: 0s - loss: 1.5021 - accuracy: 0.5490
# Epoch 13: val_accuracy did not improve from 0.62467
# 111/111 [==============================] - 198s 2s/step - loss: 1.5021 - accuracy: 0.5490 - val_loss: 1.2742 - val_accuracy: 0.6159 - lr: 0.0010
# Epoch 14/50
# 111/111 [==============================] - ETA: 0s - loss: 1.4322 - accuracy: 0.5724
# Epoch 14: val_accuracy improved from 0.62467 to 0.64969, saving model to /content/CNN_aug_best_weights.h5
# 111/111 [==============================] - 200s 2s/step - loss: 1.4322 - accuracy: 0.5724 - val_loss: 1.2084 - val_accuracy: 0.6497 - lr: 0.0010
# Epoch 15/50
# 111/111 [==============================] - ETA: 0s - loss: 1.3591 - accuracy: 0.5928
# Epoch 15: val_accuracy improved from 0.64969 to 0.68086, saving model to /content/CNN_aug_best_weights.h5
# 111/111 [==============================] - 197s 2s/step - loss: 1.3591 - accuracy: 0.5928 - val_loss: 1.0820 - val_accuracy: 0.6809 - lr: 0.0010
# Epoch 16/50
# 111/111 [==============================] - ETA: 0s - loss: 1.3024 - accuracy: 0.6107
# Epoch 16: val_accuracy improved from 0.68086 to 0.68437, saving model to /content/CNN_aug_best_weights.h5
# 111/111 [==============================] - 201s 2s/step - loss: 1.3024 - accuracy: 0.6107 - val_loss: 1.0867 - val_accuracy: 0.6844 - lr: 0.0010
# Epoch 17/50
# 111/111 [==============================] - ETA: 0s - loss: 1.2629 - accuracy: 0.6168
# Epoch 17: val_accuracy did not improve from 0.68437
# 111/111 [==============================] - 198s 2s/step - loss: 1.2629 - accuracy: 0.6168 - val_loss: 1.2097 - val_accuracy: 0.6435 - lr: 0.0010
# Epoch 18/50
# 111/111 [==============================] - ETA: 0s - loss: 1.2019 - accuracy: 0.6355
# Epoch 18: val_accuracy improved from 0.68437 to 0.72300, saving model to /content/CNN_aug_best_weights.h5
# 111/111 [==============================] - 197s 2s/step - loss: 1.2019 - accuracy: 0.6355 - val_loss: 0.9563 - val_accuracy: 0.7230 - lr: 0.0010
# Epoch 19/50
# 111/111 [==============================] - ETA: 0s - loss: 1.1367 - accuracy: 0.6556
# Epoch 19: val_accuracy improved from 0.72300 to 0.75593, saving model to /content/CNN_aug_best_weights.h5
# 111/111 [==============================] - 198s 2s/step - loss: 1.1367 - accuracy: 0.6556 - val_loss: 0.8553 - val_accuracy: 0.7559 - lr: 0.0010
# Epoch 20/50
# 111/111 [==============================] - ETA: 0s - loss: 1.1435 - accuracy: 0.6596
# Epoch 20: val_accuracy did not improve from 0.75593
# 111/111 [==============================] - 197s 2s/step - loss: 1.1435 - accuracy: 0.6596 - val_loss: 0.8698 - val_accuracy: 0.7515 - lr: 0.0010
# Epoch 21/50
# 111/111 [==============================] - ETA: 0s - loss: 1.0385 - accuracy: 0.6808
# Epoch 21: val_accuracy improved from 0.75593 to 0.78051, saving model to /content/CNN_aug_best_weights.h5
# 111/111 [==============================] - 202s 2s/step - loss: 1.0385 - accuracy: 0.6808 - val_loss: 0.7930 - val_accuracy: 0.7805 - lr: 0.0010
# Epoch 22/50
# 111/111 [==============================] - ETA: 0s - loss: 0.9627 - accuracy: 0.7073
# Epoch 22: val_accuracy improved from 0.78051 to 0.78314, saving model to /content/CNN_aug_best_weights.h5
# 111/111 [==============================] - 193s 2s/step - loss: 0.9627 - accuracy: 0.7073 - val_loss: 0.7938 - val_accuracy: 0.7831 - lr: 0.0010
# Epoch 23/50
# 111/111 [==============================] - ETA: 0s - loss: 0.9996 - accuracy: 0.6957
# Epoch 23: val_accuracy improved from 0.78314 to 0.82397, saving model to /content/CNN_aug_best_weights.h5
# 111/111 [==============================] - 193s 2s/step - loss: 0.9996 - accuracy: 0.6957 - val_loss: 0.6509 - val_accuracy: 0.8240 - lr: 0.0010
# Epoch 24/50
# 111/111 [==============================] - ETA: 0s - loss: 0.8904 - accuracy: 0.7260
# Epoch 24: val_accuracy did not improve from 0.82397
# 111/111 [==============================] - 254s 2s/step - loss: 0.8904 - accuracy: 0.7260 - val_loss: 0.7526 - val_accuracy: 0.8033 - lr: 0.0010
# Epoch 25/50
# 111/111 [==============================] - ETA: 0s - loss: 0.8814 - accuracy: 0.7272
# Epoch 25: val_accuracy did not improve from 0.82397
# 111/111 [==============================] - 195s 2s/step - loss: 0.8814 - accuracy: 0.7272 - val_loss: 0.6659 - val_accuracy: 0.8187 - lr: 0.0010
# Epoch 26/50
# 111/111 [==============================] - ETA: 0s - loss: 0.8528 - accuracy: 0.7381
# Epoch 26: val_accuracy improved from 0.82397 to 0.83099, saving model to /content/CNN_aug_best_weights.h5
# 111/111 [==============================] - 194s 2s/step - loss: 0.8528 - accuracy: 0.7381 - val_loss: 0.6128 - val_accuracy: 0.8310 - lr: 0.0010
# Epoch 27/50
# 111/111 [==============================] - ETA: 0s - loss: 0.7737 - accuracy: 0.7577
# Epoch 27: val_accuracy did not improve from 0.83099
# 111/111 [==============================] - 193s 2s/step - loss: 0.7737 - accuracy: 0.7577 - val_loss: 0.6830 - val_accuracy: 0.8183 - lr: 0.0010
# Epoch 28/50
# 111/111 [==============================] - ETA: 0s - loss: 0.7827 - accuracy: 0.7582
# Epoch 28: val_accuracy improved from 0.83099 to 0.83714, saving model to /content/CNN_aug_best_weights.h5
# 111/111 [==============================] - 194s 2s/step - loss: 0.7827 - accuracy: 0.7582 - val_loss: 0.6133 - val_accuracy: 0.8371 - lr: 0.0010
# Epoch 29/50
# 111/111 [==============================] - ETA: 0s - loss: 0.7603 - accuracy: 0.7619
# Epoch 29: val_accuracy did not improve from 0.83714
# 111/111 [==============================] - 193s 2s/step - loss: 0.7603 - accuracy: 0.7619 - val_loss: 0.6593 - val_accuracy: 0.8310 - lr: 0.0010
# Epoch 30/50
# 111/111 [==============================] - ETA: 0s - loss: 0.6998 - accuracy: 0.7846
# Epoch 30: val_accuracy improved from 0.83714 to 0.84328, saving model to /content/CNN_aug_best_weights.h5
# 111/111 [==============================] - 195s 2s/step - loss: 0.6998 - accuracy: 0.7846 - val_loss: 0.5982 - val_accuracy: 0.8433 - lr: 0.0010
# Epoch 31/50
# 111/111 [==============================] - ETA: 0s - loss: 0.6813 - accuracy: 0.7910
# Epoch 31: val_accuracy improved from 0.84328 to 0.85075, saving model to /content/CNN_aug_best_weights.h5
# 111/111 [==============================] - 191s 2s/step - loss: 0.6813 - accuracy: 0.7910 - val_loss: 0.5769 - val_accuracy: 0.8507 - lr: 0.0010
# Epoch 32/50
# 111/111 [==============================] - ETA: 0s - loss: 0.6803 - accuracy: 0.7850
# Epoch 32: val_accuracy improved from 0.85075 to 0.85514, saving model to /content/CNN_aug_best_weights.h5
# 111/111 [==============================] - 194s 2s/step - loss: 0.6803 - accuracy: 0.7850 - val_loss: 0.5773 - val_accuracy: 0.8551 - lr: 0.0010
# Epoch 33/50
# 111/111 [==============================] - ETA: 0s - loss: 0.6825 - accuracy: 0.7948
# Epoch 33: val_accuracy did not improve from 0.85514
# 111/111 [==============================] - 193s 2s/step - loss: 0.6825 - accuracy: 0.7948 - val_loss: 0.6797 - val_accuracy: 0.8240 - lr: 0.0010
# Epoch 34/50
# 111/111 [==============================] - ETA: 0s - loss: 0.6258 - accuracy: 0.8033
# Epoch 34: val_accuracy did not improve from 0.85514
# 111/111 [==============================] - 193s 2s/step - loss: 0.6258 - accuracy: 0.8033 - val_loss: 0.5954 - val_accuracy: 0.8538 - lr: 0.0010
# Epoch 35/50
# 111/111 [==============================] - ETA: 0s - loss: 0.5789 - accuracy: 0.8198
# Epoch 35: val_accuracy improved from 0.85514 to 0.88630, saving model to /content/CNN_aug_best_weights.h5
# 111/111 [==============================] - 197s 2s/step - loss: 0.5789 - accuracy: 0.8198 - val_loss: 0.5111 - val_accuracy: 0.8863 - lr: 0.0010
# Epoch 36/50
# 111/111 [==============================] - ETA: 0s - loss: 0.6128 - accuracy: 0.8080
# Epoch 36: val_accuracy did not improve from 0.88630
# 111/111 [==============================] - 193s 2s/step - loss: 0.6128 - accuracy: 0.8080 - val_loss: 0.5057 - val_accuracy: 0.8806 - lr: 0.0010
# Epoch 37/50
# 111/111 [==============================] - ETA: 0s - loss: 0.5649 - accuracy: 0.8224
# Epoch 37: val_accuracy did not improve from 0.88630
# 111/111 [==============================] - 197s 2s/step - loss: 0.5649 - accuracy: 0.8224 - val_loss: 0.6042 - val_accuracy: 0.8516 - lr: 0.0010
# Epoch 38/50
# 111/111 [==============================] - ETA: 0s - loss: 0.5394 - accuracy: 0.8297
# Epoch 38: val_accuracy did not improve from 0.88630
# 111/111 [==============================] - 193s 2s/step - loss: 0.5394 - accuracy: 0.8297 - val_loss: 0.5421 - val_accuracy: 0.8723 - lr: 0.0010
# Epoch 39/50
# 111/111 [==============================] - ETA: 0s - loss: 0.5697 - accuracy: 0.8235
# Epoch 39: val_accuracy did not improve from 0.88630
# 111/111 [==============================] - 197s 2s/step - loss: 0.5697 - accuracy: 0.8235 - val_loss: 0.5283 - val_accuracy: 0.8806 - lr: 0.0010
# Epoch 40/50
# 111/111 [==============================] - ETA: 0s - loss: 0.5176 - accuracy: 0.8463
# Epoch 40: val_accuracy did not improve from 0.88630
# 111/111 [==============================] - 194s 2s/step - loss: 0.5176 - accuracy: 0.8463 - val_loss: 0.5282 - val_accuracy: 0.8771 - lr: 0.0010
# Epoch 41/50
# 111/111 [==============================] - ETA: 0s - loss: 0.5271 - accuracy: 0.8374
# Epoch 41: val_accuracy did not improve from 0.88630
# 111/111 [==============================] - 196s 2s/step - loss: 0.5271 - accuracy: 0.8374 - val_loss: 0.5180 - val_accuracy: 0.8802 - lr: 0.0010
# Epoch 42/50
# 111/111 [==============================] - ETA: 0s - loss: 0.3834 - accuracy: 0.8815
# Epoch 42: val_accuracy improved from 0.88630 to 0.89377, saving model to /content/CNN_aug_best_weights.h5
# 111/111 [==============================] - 194s 2s/step - loss: 0.3834 - accuracy: 0.8815 - val_loss: 0.4968 - val_accuracy: 0.8938 - lr: 3.1623e-04
# Epoch 43/50
# 111/111 [==============================] - ETA: 0s - loss: 0.3327 - accuracy: 0.8976
# Epoch 43: val_accuracy improved from 0.89377 to 0.91133, saving model to /content/CNN_aug_best_weights.h5
# 111/111 [==============================] - 194s 2s/step - loss: 0.3327 - accuracy: 0.8976 - val_loss: 0.4452 - val_accuracy: 0.9113 - lr: 3.1623e-04
# Epoch 44/50
# 111/111 [==============================] - ETA: 0s - loss: 0.3092 - accuracy: 0.9058
# Epoch 44: val_accuracy improved from 0.91133 to 0.91615, saving model to /content/CNN_aug_best_weights.h5
# 111/111 [==============================] - 193s 2s/step - loss: 0.3092 - accuracy: 0.9058 - val_loss: 0.4422 - val_accuracy: 0.9162 - lr: 3.1623e-04
# Epoch 45/50
# 111/111 [==============================] - ETA: 0s - loss: 0.2984 - accuracy: 0.9068
# Epoch 45: val_accuracy improved from 0.91615 to 0.91835, saving model to /content/CNN_aug_best_weights.h5
# 111/111 [==============================] - 197s 2s/step - loss: 0.2984 - accuracy: 0.9068 - val_loss: 0.4273 - val_accuracy: 0.9183 - lr: 3.1623e-04
# Epoch 46/50
# 111/111 [==============================] - ETA: 0s - loss: 0.2795 - accuracy: 0.9127
# Epoch 46: val_accuracy did not improve from 0.91835
# 111/111 [==============================] - 193s 2s/step - loss: 0.2795 - accuracy: 0.9127 - val_loss: 0.4682 - val_accuracy: 0.9166 - lr: 3.1623e-04
# Epoch 47/50
# 111/111 [==============================] - ETA: 0s - loss: 0.2895 - accuracy: 0.9099
# Epoch 47: val_accuracy did not improve from 0.91835
# 111/111 [==============================] - 190s 2s/step - loss: 0.2895 - accuracy: 0.9099 - val_loss: 0.4507 - val_accuracy: 0.9144 - lr: 3.1623e-04
# Epoch 48/50
# 111/111 [==============================] - ETA: 0s - loss: 0.2832 - accuracy: 0.9129
# Epoch 48: val_accuracy did not improve from 0.91835
# 111/111 [==============================] - 194s 2s/step - loss: 0.2832 - accuracy: 0.9129 - val_loss: 0.4545 - val_accuracy: 0.9109 - lr: 3.1623e-04
# Epoch 49/50
# 111/111 [==============================] - ETA: 0s - loss: 0.2835 - accuracy: 0.9135
# Epoch 49: val_accuracy improved from 0.91835 to 0.92011, saving model to /content/CNN_aug_best_weights.h5
# 111/111 [==============================] - 193s 2s/step - loss: 0.2835 - accuracy: 0.9135 - val_loss: 0.4464 - val_accuracy: 0.9201 - lr: 3.1623e-04
# Epoch 50/50
# 111/111 [==============================] - ETA: 0s - loss: 0.2490 - accuracy: 0.9204
# Epoch 50: val_accuracy improved from 0.92011 to 0.92537, saving model to /content/CNN_aug_best_weights.h5
# 111/111 [==============================] - 192s 2s/step - loss: 0.2490 - accuracy: 0.9204 - val_loss: 0.4384 - val_accuracy: 0.9254 - lr: 3.1623e-04

# %% [markdown]
# 6. Hasil Training

# %% [markdown]
# Grafik hasil training dan validasi berdasarkan akurasi:

# %% [markdown]
# Terdapat sedikit perbedaan pada grafik training(tertinggi sekitar 0.4)dan validation (tertinggi sekitar 0.7), namun sepertinya tidak begitu jauh untuk dinilai overfitting.

# %%
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc))

fig = plt.figure(figsize=(14,7))
plt.plot(epochs, acc, 'r', label="Training Accuracy")
plt.plot(epochs, val_acc, 'b', label="Validation Accuracy")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# Grafik training dan validasi berdasarkan loss:

# %% [markdown]
# Hasil mirip dengan grafik akurasi.

# %%
fig2 = plt.figure(figsize=(14,7))
plt.plot(epochs, loss, 'r', label="Training Loss")
plt.plot(epochs, val_loss, 'b', label="Validation Loss")
plt.legend(loc='upper right')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and validation loss')
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %% [markdown]
# 7. Testing Model

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.utils import load_img, img_to_array

def preprocess_image(path):
    img = load_img(path, target_size = (img_height, img_width))
    a = img_to_array(img)
    a = np.expand_dims(a, axis = 0)
    a /= 255.
    return a

# %%
test_images_dir = os.path.join(base_dir, 'test/')
test_df = pd.read_csv(os.path.join(base_dir, 'test_set.csv'))

test_dfToList = test_df['filename'].tolist()
test_ids = [str(item) for item in test_dfToList]

test_images = [test_images_dir + item for item in test_ids]
test_preprocessed_images = np.vstack([preprocess_image(fn) for fn in test_images])
np.save('/content/test_preproc_CNN.npy', test_preprocessed_images)

# %%
array = model.predict(test_preprocessed_images, batch_size=1, verbose=1)
answer = np.argmax(array, axis=1)
#print(answer)
#print(answer[20])
# Out:
# 222/222 [==============================] - 1s 2ms/step

# %%
test_df = pd.read_csv(os.path.join(base_dir, 'test_set.csv'))
y_true = test_df['class']
y_pred = array
#print(y_true[20])
#for i in y_true:
#  print(y_true[i] + y_pred[i])

# %%
from sklearn.metrics import log_loss
loss = log_loss(y_true, y_pred, eps=1e-15, normalize=True, sample_weight=None, labels=None)

# %%
print(loss)
# Out:
# 0.3473372836399723

# %% [markdown]
# Pembuatan confusion matrix untuk menganalisa prediksi label yang salah.

# %%
from sklearn.metrics import confusion_matrix
conf_mat = confusion_matrix(y_true, answer)
conf_mat
# Out:
# array([[5, 0, 1, ..., 0, 0, 0],
#        [0, 6, 0, ..., 0, 0, 0],
#        [0, 0, 6, ..., 0, 0, 0],
#        ...,
#        [0, 0, 0, ..., 6, 0, 0],
#        [0, 0, 0, ..., 0, 5, 0],
#        [0, 0, 0, ..., 0, 0, 6]])

# %%
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Reds):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = cm.round(2)
    else:
        cm=cm


    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %% [markdown]
# Hasil confusion matrix cukup bagus. Bila dilihat kebanyakan data berada di garis diagonal yang berarti hasil prediksi sesuai dengan label sebenarnya.

# %%
np.set_printoptions(precision=2)

fig1 = plt.figure(figsize=(37,14))
plot_confusion_matrix(conf_mat, classes=classes, title='Confusion matrix, without normalization')
plt.show()
